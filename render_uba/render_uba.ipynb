# %% [markdown]
# # Presentaciones Docencia UBA
#
# Armar las cosas en formato para UBA

# %%
import yaml

with open('../cv_db/cv_es.yaml', 'r', encoding='utf-8') as file:
    cv_data = yaml.safe_load(file)

# Print the loaded data to verify
print(cv_data)
# Out:
# {'Resumen': {'free_text': ['A lo largo de mi trayectoria profesional, he desarrollado un perfil multidisciplinario en biología y física, abarcando tanto enfoques teóricos como experimentales. Tras completar el ciclo troncal de medicina, orienté mi formación hacia las ciencias físicas, especializándome en biofísica y estadística para profundizar en la cuantificación de fenómenos biológicos. Durante mi doctorado y en los años posteriores, me he centrado en técnicas de microscopía, integrando el desarrollo experimental con el modelado matemático para abordar diversas preguntas de investigación. Además, he disfrutado impartiendo docencia en estadística, física, microscopía, análisis de imágenes y trabajo de laboratorio, enseñando a estudiantes de física y biología. Actualmente, me desempeño como analista de imágenes en BioImage Informatics Facility, donde brindo soporte en el desarrollo de secuencias de análisis de imágenes, al tiempo que continúo ampliando y compartiendo conocimientos e
# ...

# %% [markdown]
# ## Antecedentes Docentes
#
# Levantar antecedented docentes en formato:
#
# Indicando jerarquía docente, carácter del cargo (regular/interino), Institución (Universidad, Facultad, Departamento) y período de ejercicio.
#
# Cursos de grado en los que enseñó.
#
# Cursos de posgrado en los que enseñó.

# %%
for content in cv_data['Experiencia']['Docencia y Formación']:
    print(f"{content['name']}, regular, {content['location']}, {content['date']}")
    print("\t" + "\n\t".join(content['description']))
    print("\n")
# Out:
# Profesor invitado, regular, Sveriges lantbruksuniversitet, Universidad de Ciencias de la agricultura de Suecia, 2025
# 	Curso de 3 semanas
# 	*AI Tools in Biology*: Seminario teórico y práctico sobre inteligencia artificial en análisis de bioimágenes.
#
#
# Profesor invitado, regular, Center for Cellular Imaging, Universidad de Gotemburgo, 2024
# 	Curso intensivo de 1 semana
# 	**Introducción al análisis de bioimágenes**: Curso teórico y práctico sobre análisis de imágenes orientado a biología.
#
#
# Profesor invitado y facilitador, regular, Live Cell Imaging, Karolinska Institutet, 2025
# 	Curso intensivo de 3 semanas
# 	**Microscopy: Improve Your Imaging Skills - From Sample Preparation to Image Analysis**: Curso teórico y práctico sobre diseño experimental en microscopía.
# 	[Link a video](https://www.youtube.com/watch?v=tqiq2wKrMLY)
#
#
# Ayudante, regular, National Bioinformatics Infrastructure Sweden, Bioimage Informatics, Uppsala Universitet, 2024
# ...

# %% [markdown]
# Profesor invitado, regular, Sveriges lantbruksuniversitet, Universidad de Ciencias de la agricultura de Suecia, 2025
# 	Curso de 3 semanas
# 	*AI Tools in Biology*: Seminario teórico y práctico sobre inteligencia artificial en análisis de bioimágenes.
#
#
# Profesor invitado, regular, Center for Cellular Imaging, Universidad de Gotemburgo, 2024
# 	Curso intensivo de 1 semana
# 	**Introducción al análisis de bioimágenes**: Curso teórico y práctico sobre análisis de imágenes orientado a biología.
#
#
# Profesor invitado y facilitador, regular, Live Cell Imaging, Karolinska Institutet, 2025
# 	Curso intensivo de 3 semanas
# 	**Microscopy: Improve Your Imaging Skills - From Sample Preparation to Image Analysis**: Curso teórico y práctico sobre diseño experimental en microscopía.
# 	[Link a video](https://www.youtube.com/watch?v=tqiq2wKrMLY)
#
#
# Ayudante, regular, National Bioinformatics Infrastructure Sweden, Bioimage Informatics, Uppsala Universitet, 2024
# 	Curso intensivo de 1 semana
# 	**Neural networks and Deep Learning**: Curso teórico y práctico sobre diseño de redes neurales.
#
#
# Ayudante (Facilitador), regular, Live Cell Imaging Facility, Karolinska Institutet, 2024
# 	Curso intensivo de 3 semanas
# 	**Microscopy: Improve Your Imaging Skills - From Sample Preparation to Image Analysis**: Curso teórico y práctico sobre diseño experimental en microscopía.
#
#
# Supervisión de Estudiante de Master, regular, Departamento de Biología Celular y Molecular, Karolinska Institutet, 2024
# 	Proyecto de 4 meses
# 	Exploring liver embryonic progenitors and at what extend they can be manipulated: Analysis of GSK126 effects on the differentiation of liver progenitor cells in vitro
#
#
# Supervisión de Estudiante, regular, Departamento de Biología Celular y Molecular, Karolinska Institutet, 2023--2024
# 	Estudiante de Bachelor
# 	Su proyecto consistía en hacer clearing de cortes gruesos de hígado y luego adquirir y analizar imágenes de microscopía.
#
#
# Jefe de Trabajos Prácticos, regular, Facultad de Ciencias Exactas y Naturales, U.B.A., 2019-Curso de verano
# 	Dedicación Simple, 20hs. semanales
# 	Laboratorio 3
#
#
# Ayudante Primera, regular, Facultad de Ciencias Exactas y Naturales, U.B.A., 2017-2021
# 	Dedicación Simple, 10hs. semanales
# 	Instrumentación y Control
# 	Laboratorio 5
# 	Laboratorio 3
# 	Microscopía Óptica y de Fluorescencia I
# 	Física 1 para Biólogos y Geólogos
#
#
# Ayudante Segunda, regular, Facultad de Ciencias Exactas y Naturales, U.B.A., 2015--2017
# 	10 hs. semanales
# 	Física 1 y 2 para Biólogos y Geólogos
# 	Laboratorio 1 para Químicos
# 	Laboratorio 5
#
#
# Ayudante Segunda, regular, Facultad de Ciencias Biomédicas, Hospital Universitario Austral, 2010
# 	10 hs. semanales
# 	Medicina Celular y Molecular
#
#
# Taller de Programación en Python y \LaTeX, regular, Facultad de Ciencias Exactas y Naturales, U.B.A., 2014--2015
# 	3 clases de 3 hs. una vez por cuatrimestre
# 	Organización, difusión y presentación del Taller
#
#
# Instituto Profesores Particulares, regular, Buenos Aires, Argentina, 2013
# 	Profesor Particular, Octubre y Noviembre
#
#
# Taller de Programación en \LaTeX, regular, Facultad de Ciencias Exactas y Naturales, U.B.A., 2013
# 	en ambos cuatrimestres
# 	Organización, difusión y presentación del Taller
#
#
# Clases Particulares, regular, Buenos Aires, Argentina, 2011-2013
# 	Clases Particulares de: Física, Matemática, Química, Biología, Biofísica.
# 	Nivel Primario, Secundario y Universitario.

# %% [markdown]
# ## Antecedentes Cientificos
#
# a) Trabajos publicados
#
# (El jurado podrá requerir que se presenten copias de las publicaciones y trabajos inéditos realizados, que serán devueltas una vez sustanciado el concurso. En todos los casos se deberá indicar los/as coautores/as).
#
#     i)	Publicaciones con arbitraje.
#
#         a) revistas (se pueden citar las aceptadas; para las publicaciones aceptadas que no estén online se debe presentar correo electrónico del editor indicando la aceptación).
#         b) en actas de conferencias.
#     ii) Artículos enviados a revistas con arbitraje y aún no aceptados.
#     iii) Publicaciones sin arbitraje.
#
# b) Participación en congresos o acontecimientos nacionales o internacionales (indicar lugar, fecha y comunicaciones que presentó o si sólo asistió).
#
# c) Formación de Recursos Humanos.
#
# Tesis, becas en cuya supervisión colaboró.
#
# d) Participación en Proyectos de Investigación.
#
# Indicando el grado de participación.
#
# e) Cursos de Posgrado no incluidos en la carrera de Doctorado.
# Materias, cursos y seminarios realizados por el/ la aspirante y que se consideren formativos para su capacitación científica, salvo los correspondientes a la Carrera del Doctorado.
#
# f) Otros antecedentes científicos no considerados en los puntos anteriores

# %%
for content in cv_data['Producción']['Publicaciones']:
    print(f"{content['authors']}, ({content['date']}), {content['title']}, {content['journal']}, {', '.join(content['description'])}")
    print("\n")
# Out:
# Sandra de Haan, Jingyan He, **Agustin A. Corbat**, Lenka Belicova, Michael Ratz, Elin Vinsland, Sten Linnarsson, Jonas Frisén, Matthew W. Kelley, Emma R. Andersson, (2025), Ectoderm barcoding reveals neural and cochlear compartmentalization, Science, doi: https://doi.org/10.1126/science.adq9248
#
#
# María G. Thomas, Ana J. Fernández-Alvarez, Macarena Giménez, Francisco C. Aristarain, Lucas H. Cozza, Jerónimo Pimentel, João Pessoa, Malena L. Pascual, Lara Boscaglia, Martín Habif, **Agustín Corbat**, Pablo E. La Spina, Tomás Peters, Diego M. Bustos, Maria Carmo-Fonseca, Hernán E. Grecco, Graciela L. Boccaccio, (2025), The non-canonical Smoothened-AMPK axis regulates Smaug1 biomolecular condensates, Journal of Cell Science, doi: https://doi.org/10.1242/jcs.263433
#
#
# ...

# %% [markdown]
# Sandra de Haan, Jingyan He, **Agustin A. Corbat**, Lenka Belicova, Michael Ratz, Elin Vinsland, Sten Linnarsson, Jonas Frisén, Matthew W. Kelley, Emma R. Andersson, (2025, Ectoderm barcoding reveals neural and cochlear compartmentalization, Science, doi: https://doi.org/10.1126/science.adq9248
#
#
# María G. Thomas, Ana J. Fernández-Alvarez, Macarena Giménez, Francisco C. Aristarain, Lucas H. Cozza, Jerónimo Pimentel, João Pessoa, Malena L. Pascual, Lara Boscaglia, Martín Habif, **Agustín Corbat**, Pablo E. La Spina, Tomás Peters, Diego M. Bustos, Maria Carmo-Fonseca, Hernán E. Grecco, Graciela L. Boccaccio, (2025, The non-canonical Smoothened-AMPK axis regulates Smaug1 biomolecular condensates, Journal of Cell Science, doi: https://doi.org/10.1242/jcs.263433
#
#
# Sandra de Haan, **Agustin Corbat**, Christopher R. Cederroth, Lisa G. Autrum, Simona Hankeova, Elizabeth C. Driver, Barbara Canlon, Matthew W. Kelley, Emma R. Andersson, (2024, Jag1 represses Notch activation in lateral supporting cells and inhibits an outer hair cell fate in the medial cochlea, Development, Year: 2024; doi: https://doi.org/10.1242/dev.202949
#
#
# Mariano Salgueiro, Gabriela Camporeale, Araceli Visentin, Martin Aran, Leonardo Pellizza, Sebastián A. Esperante, **Agustín Corbat**, Hernán Grecco, Belén Sousa, Ramiro Esperón, Silvia S. Borkosky, Gonzalo de Prat-Gay, (2023, Molten Globule Driven and Self-downmodulated Phase Separation of a Viral Factory Scaffold, Journal of Molecular Biology, Year: 2023; doi: https://doi.org/10.1016/j.jmb.2023.168153
#
#
# Ana J. Fernández-Alvarez, María Gabriela Thomas, Malena L. Pascual, Martín Habif, Jerónimo Pimentel, **Agustin A. Corbat**, João P. Pessoa, Pablo E. La Spina, Lara Boscaglia, Anne Plessis, Maria Carmo-Fonseca, Hernán E. Grecco, Marta Casado, Graciela L. Boccaccio, (2021, Smaug1 membrane-less organelles respond to AMPK and mTOR and affect mitochondrial function, Journal of Cell Science, Año: 2021; doi: https://doi.org/10.1242/jcs.253591
#
#
# **Agustin A. Corbat**, Mauro Silberberg, Hernán E. Grecco, (2021, An Integrative Apoptotic Reaction Model for extrinsic and intrinsic stimuli, BioRxiv, Año: 2021
#
#
# Martín Habif*, **Agustin A. Corbat***, Mauro Silberberg, Hernán E. Grecco, (2021, CASPAM: a triple modality biosensor for multiplexed imaging of caspase network activity, bioRxiv, ACS Sensors, *Autores contribuyeron equitativamente, Año: 2021; doi: https://doi.org/10.1101/2021.03.10.434623
#
#
# **Agustin A. Corbat**, Klaus C. Schuermann, Piotr Liguzinski, Yvonne Radon, Philippe I.H. Bastiaens, Peter J. Verveer, Hernán E. Grecco, (2018, Co-imaging extrinsic, intrinsic and effector caspase activity by fluorescence anisotropy microscopy, REDOX Biology, Publicado, Volumen: 19; Emisión: Junio; Páginas: 210-217, doi: 10.1016/j.redox.2018.07.023

# %%
for content in cv_data['Producción']['Posters y Presentaciones Orales']:
    try:
        print(f"{content['event']}, {content['location']}, {content['date']}, {content['name']}, {content['authors']}, {', '.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Imaging The Future, Austin, Texas, Estados Unidos, 2024, Demostración de TissUUmaps, **Corbat, Agustin**, Presentación de software
#
#
# Imaging The Future, Austin, Texas, Estados Unidos, 2024, The Three Gears of Bioscience Projects, **Corbat, Agustin**, Presentación de póster, [Link](https://figshare.com/articles/poster/The_Three_Gears_of_Bioscience_Projects/27725865?file=50481666)
#
#
# GloBIAS in-person Workshop, Universidad de Gotenburgo, Suecia, 2024, On Navigating the archipelago, **Corbat, Agustin**, Presentación, [Diapositivas](https://github.com/GloBIAS-BioimageAnalysts/workshop24_Gothenburg/blob/main/Training_and_Education_Corbat_On_navigating.pptx), [Video](https://www.youtube.com/watch?v=uKQ2OsPboi0)
#
#
# ...

# %% [markdown]
# Imaging The Future, Austin, Texas, Estados Unidos, 2024, Demostración de TissUUmaps, **Corbat, Agustin**, Presentación de software
#
#
# Imaging The Future, Austin, Texas, Estados Unidos, 2024, The Three Gears of Bioscience Projects, **Corbat, Agustin**, Presentación de póster, [Link](https://figshare.com/articles/poster/The_Three_Gears_of_Bioscience_Projects/27725865?file=50481666)
#
#
# GloBIAS in-person Workshop, Universidad de Gotenburgo, Suecia, 2024, On Navigating the archipelago, **Corbat, Agustin**, Presentación, [Diapositivas](https://github.com/GloBIAS-BioimageAnalysts/workshop24_Gothenburg/blob/main/Training_and_Education_Corbat_On_navigating.pptx)
#
#
# GloBIAS in-person Workshop, Universidad de Gotenburgo, Suecia, 2024, Interfacing with other networks, **Corbat, Agustin**, Presentación, [Diapositivas](https://docs.google.com/presentation/d/13qqOv7V2_8JLehdJA6WURrcpjyz1M2qC/edit), [Documento](https://docs.google.com/document/d/1miWe3rwJYZl7-Edv8yOys7_iOyKxhlioFZdh9h6Qu-8/edit?tab=t.0)
#
#
# I2K: Images to Knowledge, Human Technopole, Milán, Italia, 2024, Multiplexed tissue imaging: tools and approaches, **Corbat, Agustin**; Klemm, Anna; Ballosera Navarro, Frederic; Windhager, Jonas; Lidayová, Kristína, Taller de 90 minutos
#
#
# SciLifeLab Spatial Biology Science Summit, Uppsala Universitet, Uppsala, Suecia, 2024, Bioimage Informatics Facility, **Corbat, Agustin**, Presentación de póster
#
#
# Whole Cell Modelling Summer School 2019, EMBO Workshop, Barcelona, España, 2019, Unravelling apoptotic signalling cascade by co-imaging extrinsic, intrinsic and effector caspase activity by fluorescence anisotropy microscopy, Corbat, Agustín A.; Grecco, Hernán E., Presentación de póster
#
#
# Systems Biology of Cancer: Promises of Artificial Intelligence; EMBO|FEBS Lecture Course, Institut Curie, Paris, France, 2020, Unravelling apoptotic signalling cascade by co-imaging extrinsic, intrinsic and effector caspase activity by fluorescence anisotropy microscopy, Corbat, Agustín A.; Grecco, Hernán E., Charla seleccionada y presentación de póster, Encuentro Virtual
#
#
# Image-based Systems Biology, 5^th^ International Symposium, Hans-Knöll Institute, University of Jena, Germany, 2020, Unravelling apoptotic signalling cascade by co-imaging extrinsic, intrinsic and effector caspase activity by fluorescence anisotropy microscopy, Corbat, Agustín A.; Silberberg, Mauro; Grecco, Hernán E., Charla en tandem seleccionada y presentación de póster, Encuentro Virtual
#
#
# Biophysical Journal, San Diego, California, Estados Unidos, 2020, Molten Globule Driven Liquid-Liquid Phase Separation at the Center of Viral Factory Assembly, Salgueiro, Mariano; Camporeale, Gabriela; Conci, Julieta; Sousa, Belen; Visentin, Araceli; Corbat, Agustin; Grecco, Hernan; de Oliveira, Guilherme A.; de Prat-Gay, Gonzalo, Presentación de póster a cargo de Mariano Sagueiro
#
#
# Taller de Biología Celular y del Desarrollo, Chascomús, Buenos Aires, Argentina, 2018, Towards a spatio-temporal map of apoptosis in fruit fly embryo, Moretti, Bruno; Corbat, Agustín A.; Habif, Martín; Grecco, Hernán E., Presentación de póster a cargo de Bruno Moretti
#
#
# Giambiagi Winter School, Facultad de Ciencias Exactas y Naturales, U.B.A., 2018, Co-imaging extrinsic, intrinsic and effector caspase activity by fluorescence anisotropy microscopy, Corbat, Agustín and Grecco, Hernán, Presentación de póster
#
#
# SPCell2018, São Paulo School in Advanced Cell Biology, University of São Paulo, Brazil, 2018, A single plasmid based triple-modality-reporter-system for multiplexing caspase activity in individual cells, Habif, Martín; Corbat, Agustín; Grecco, Hernán, Presentación de Póster a cargo de Martín Habif, Co-organizado por EMBO y American Society of Cell Biology (ASCB)
#
#
# Annual Meeting of International Physics of Living Systems (iPoLS) Network, Paris, France, 2017, Integrating functional imaging with light sheet fluorescence microscopy, Moretti, Bruno; Corbat, Agustín; Habif, Martín; Grecco, Hernán, Presentación de Póster
#
#
# Frontiers in Bioscience 2, Insituto de Biología de Buenos Aires, Buenos Aires, Argentina, 2016, Modeling Caspase Dynamics from Temporal Series, Corbat, Agustín; Grecco, Hernán, Presentación de Póster
#
#
# Frontiers in Bioscience 2, Insituto de Biología de Buenos Aires, Buenos Aires, Argentina, 2016, A triple-modality-reporter system for multiplexing intracellular signaling at the single cell level, Habif, Martín; Corbat, Agustín; Grecco, Hernán, Presentación de Póster
#
#
# Reunión Nacional de Física N^o^ 101, Villa de Merlo, San Luis, Argentina, 2016, Modelado de experimentos de homoFRET en red de señalización de apoptosis, Corbat, Agustín; Grecco, Hernán, Presentación de Póster
#
#
# Sistema Optomecánica Abierta, Buenos Aires, Argentina, 2015, Proyecto Tecnológico, Proyecto SOMA, 2º premio en INNOVAR 2015, Dispositivos electromecánicos para experimentos de óptica confeccionados con impresora 3D y controlados por una placa Arduino., http://www.lec.df.uba.ar/soma/
#
#
# Reunión Nacional de Física N^o^ 100, Tandil, Buenos Aires, Argentina, 2015, Sistema Opto-mecánico Abierto, Cuenca, Marina; Corbat, Agustín; von Bilderling, Catalina; Pietrasanta, Lia; Grecco, Hernán, Póster
#
#
# Giambiagi Winter School, Facultad de Ciencias Exactas y Naturales, U.B.A., 2015, Open Source Fast Filter Wheel, Corbat, Agustín; Cuenca, Marina; von Bilderling, Catalina; Pietrasanta, Lia; Grecco, Hernán, Póster

# %% [markdown]
# ### Participación en Proyectos de Investigación.
#
# Indicando el grado de participación.

# %%
for content in cv_data['Experiencia']['Proyectos']:
    try:
        print(f"{content['name']}, {content['date']}, {content['location']}.\n{'\n'.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Spatial Profiling of the renal host-pathogen interplay in response to Candida albicans infection in mice, 2025, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación BioImage Informatics Facility. '[Descripcion del proyecto](https://biifsweden.github.io/projects/2025/02/25/PerLjungdahl2025-1/)' '[Repsoitorio del codigo](https://github.com/BIIFSweden/PerLjungdahl2025-1)'
#
#
# Segmentation of cavernous malformations using MRI scans of mouse brain, 2024, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación como parte de BioImage Informatics Facility. '[Descripcion del proyecto](https://biifsweden.github.io/projects/2024/09/01/PeetraMagnusson2024-1/)'
#
#
# ...

# %% [markdown]
# Spatial Profiling of the renal host-pathogen interplay in response to Candida albicans infection in mice, 2025, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación BioImage Informatics Facility. '[Descripcion del proyecto](https://biifsweden.github.io/projects/2025/02/25/PerLjungdahl2025-1/)' '[Repsoitorio del codigo](https://github.com/BIIFSweden/PerLjungdahl2025-1)'
#
#
# Segmentation of cavernous malformations using MRI scans of mouse brain, 2024, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación como parte de BioImage Informatics Facility. '[Descripcion del proyecto](https://biifsweden.github.io/projects/2024/09/01/PeetraMagnusson2024-1/)'
#
#
# The role of perivascular TAM phenotypes in metastatic dissemination, 2024, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación como parte de BioImage Informatics Facility. '[Descripcion del proyecto](https://biifsweden.github.io/projects/2024/07/10/CharlotteRolny2024-1/)'
#
#
# AI4Life Open Call 2: Project 11, 2024, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación como parte de AI4Life Open Call 2. '[Descripcion del proyecto](https://github.com/ai4life-opencalls/oc_2_project_11)'
#
#
# AI4Life Open Call 2: Project 38, 2024, BioImage Informatics Facility, ScilifeLab y National Bioinformatics Infrastructure Sweden (NBIS).
# Desarrollo de algoritmos de análisis de imágenes para proyectos de investigación como parte de AI4Life Open Call 2. '[Descripcion del proyecto](https://github.com/ai4life-opencalls/oc_2_project_38)'
#
#
# Jag1 represses Notch activation in lateral supporting cells and inhibits an outer hair cell fate in the medial compartment of the developing cochlea, 2023--2024, Emma Andersson Lab, Karolinska Institutet, Estocolmo, Suecia.
# supervisor: Dr. Emma R. Andersson
#
#
# Spatially segregated defects and IGF1-responsiveness of hilar and peripheral biliary organoids from a model of Alagille syndrome, 2023, Emma Andersson Lab, Karolinska Institutet, Estocolmo, Suecia.
# supervisor: Dr. Emma R. Andersson
#
#
# Decoding cell fate with lineage-tracing in utero transduction, 2022--2024, Emma Andersson Lab, Karolinska Institutet, Estocolmo, Suecia.
# Supervisor: Dr. Emma R. Andersson
# Knut och Alice Wallenbergs Stiftelse (Fundación Knut y Alice Wallenberg).
# Co-supervisores: Igor Adameyko, Niklas Björkström, Jonas Frisén, Ulrika Marklund.
#
#
# Tuning Notch and mechanics to engineer cell fate, 2022--2024, Emma Andersson Lab, Karolinska Institutet, Estocolmo, Suecia.
# supervisor: Dr. Emma R. Andersson
# Marie Skłodowska-Curie Actions: Seal of Excellence.
# Funded by Vetenskapsrådet (Consejo de Investigaciones de Suecia).
#
#
# Visualizing early tumorigenesis via beta-catenin oncomeme in murine intestinal organoids, 2019--2021, Systemic Cell Biology, Max Planck Institute for Molecular Physiology.
# Dr. Philippe Bastiaens
# 7 semanas en el exterior y se continua trabajando remoto durante 12 meses
#
#
# PICT-2017-1160, Diseño y construcción de un prototipo de microscopio de fluorescencia miniaturizado, de bajo costo, para aplicaciones en neurociencias y medicina, 2017--2021, Facultad de Ciencias Exactas y Naturales, University of Buenos Aires.
# En carácter de becario doctoral
#
#
# PICT-2014-3744, Correlación y causalidad: microscopía multiparamétrica de señales celulares, 2016--2021, Facultad de Ciencias Exactas y Naturales, University of Buenos Aires.
# En carácter de becario doctoral
#
#
# Beca Estímulo, 2014-2016, Laboratorio de Electrónica Cuántica, Facultad de Ciencias Exactas, U.B.A..
# Proyecto: Caracterización de nanoemisores para terapia fotodinámica cuantificando la respuesta apoptótica mediante microscopía por anistropía de fluorescencia
# Director: Dr. Hernán E. Grecco
#
#
# Células madres mesenquimales de médula ósea para regeneración y transferencia de genes terapéuticos en la cirrosis hepática, 2010, Laboratorio de Terapia Génica, Hospital Universitario Austral.
# supervisor: Dr. Jorge B. Aquino

# %% [markdown]
# # Cursos y Congresos

# %%
for content in cv_data['Cursos y Congresos']:
    try:
        print(f"{content['name']}, {content['date']}, {content['location']}, Duración: {content['extension']}, Idioma: {content['language']}.\n{'\n'.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Bioinformatics Swedish Week (Semana de Bioinformática Sueca), 2023, Karolinska Institutet, Estocolmo, Suecia, Duración: 16 hs, Idioma: Inglés.
# Asistencia y curso
#
#
# Advanced Methods in Bioimage Analysis, 2023, EMBO, Heidelberg, Alemania, Duración: 50 hs, Idioma: Inglés.
# Curso hibrido
# Participante Virtual
#
#
# GPU Programming: Why, When and How?, 2023, EuroCC National Competence Centre, Sweden, Duración: 16 hs, Idioma: Inglés.
# Curso Online
#
#
# Programming Formalisms, 2023, High Performance Computing Center North and UPPMAX, Duración: 40 hs, Idioma: Inglés.
# Curso Online
#
#
# Using Python in an HPC environment, 2023, High Performance Computing Center North and UPPMAX, Duración: 6 hs, Idioma: Inglés.
# Curso Online
#
#
# Advanced Deep Learning with Transformers, 2023, EuroCC National Competence Centre Sweden, Duración: 16 hs, Idioma: Inglés.
# Curso Online
#
#
# ...

# %% [markdown]
# Bioinformatics Swedish Week (Semana de Bioinformática Sueca), 2023, Karolinska Institutet, Estocolmo, Suecia, Duración: 16 hs, Idioma: Inglés.
# Asistencia y curso
#
#
# Advanced Methods in Bioimage Analysis, 2023, EMBO, Heidelberg, Alemania, Duración: 50 hs, Idioma: Inglés.
# Curso hibrido
# Participante Virtual
#
#
# GPU Programming: Why, When and How?, 2023, EuroCC National Competence Centre,  Sweden, Duración: 16 hs, Idioma: Inglés.
# Curso Online
#
#
# Programming Formalisms, 2023, High Performance Computing Center North and UPPMAX, Duración: 40 hs, Idioma: Inglés.
# Curso Online
#
#
# Using Python in an HPC environment, 2023, High Performance Computing Center North and UPPMAX, Duración: 6 hs, Idioma: Inglés.
# Curso Online
#
#
# Advanced Deep Learning with Transformers, 2023, EuroCC National Competence Centre Sweden, Duración: 16 hs, Idioma: Inglés.
# Curso Online
#
#
# Data-Driven Precision Medicine and Diagnostics Research Area Symposium, 2022, Estocolmo, Karolinska Institutet, Duración: 8 hs, Idioma: Inglés.
# Asistencia
#
#
# Data-Driven research at Karolinska Institutet, 2022, Estocolmo, Karolinska Institutet, Duración: 4 hs, Idioma: Inglés.
# Asistencia
#
#
# Stem cells, regeneration biology and regenerative medicine, 2022, Estocolmo, Karolinska Institutet, Duración: 2^nd^ StratRegen Conferencia, 8hs, Idioma: Inglés.
# Asistencia
#
#
# Systems Biology of Cancer: Promises of Artificial Intelligence, 2020, Institut Curie, Paris, France, Duración: 40 hs, Idioma: Inglés.
# Curso virtual de EMBO|FEBS
# Asistencia, charla seleccionada y presentación de póster
#
#
# Image-based Systems Biology, 2020, Hans-Knöll Institute, University of Jena, Germany, Duración: 16 hs, Idioma: Inglés.
# Quinto Simposio Internacional
# Asistencia, charla en tandem seleccionada y presentación de póster
# Encuentro virtual
#
#
# Whole Cell Modelling Summer School, 2019, Centre for Genomic Regulation, European Molecular Biology Organization, Barcelona, España, Duración: Escuela de 50 horas, Idioma: Inglés.
# Asistencia y presentación de póster
# Becado por European Molecular Biology Organization y organización del curso
#
#
# Quantitative Imaging: From Acquisition to Analysis, 2018, Cold Spring Harbor Laboratory (CSHL). New York, USA., Duración: Escuela de 156 horas, Idioma: Inglés.
# Media beca por Helmsley Charitable Trust y Howard Hughes Medical Institute
#
#
# School on Physics Applications in Biology, 2018, International Center for Theoretical Physics (ICTP) - South American Institute for Fundamental Research (SAIFR). S\~ao Paulo, Brasil., Duración: Escuela de 50 hs, Idioma: Inglés.
# Traslado, alojamiento, mantenimiento y becado por ICTP
#
#
# Escuela de Ciencias Informáticas: "Bayesian Models in Machine Learning", 2017, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: Curso de 15 hs., Idioma: Inglés.
# Lukáš Burget. Brno University of Technology. República Checa.
# Asistencia y Presentación Monografía (Nota:8)
#
#
# Escuela de Ciencias Informáticas: "Machine learning for analyzing neuroimaging data from natural stimulus experiments", 2017, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: Curso de 15 hs., Idioma: Inglés.
# Alex Huth. UC Berkeley. Estados Unidos.
# Asistencia y Presentación Monografía (Nota:8)
#
#
# Escuela de Ciencias Informáticas: "Clasificación de estados cerebrales utilizando neuroimágenes funcionales", 2017, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: Curso de 15 hs., Idioma: Español.
# Enzo Tagliazucchi. Brain and Spine Institute. Paris, Francia
# Asistencia y Presentación Monografía (Nota:8)
#
#
# Simposium Frontiers in Bioscience 2, 2016, Instituto de Biología de Buenos Aires, Buenos Aires, Argentina, Duración: Simposio de 1 semana, Idioma: Inglés.
# Asistencia y Presentación póster
#
#
# 101$^a$ Reunión Nacional de la Asociación Física Argentina, 2016, Villa de Merlo, San Luis, Argentina, Duración: Congreso de 1 semana, Idioma: Español.
# Asistencia y Presentación póster
#
#
# 100$^a$ Reunión Nacional de la Asociación Física Argentina, 2015, Tandil, Buenos Aires, Argentina, Duración: Congreso de 1 semana, Idioma: Español.
# Asistencia y Presentación oral
#
#
# Light and light based technologies, 2015, Facultad de Ciencias Exactas y Naturales, U.B.A, Duración: Congreso de 1 semana, Idioma: Inglés.
# Giambiagi XVII Winter School
# Asistencia
#
#
# Técnicas para manipulación de frecuencias de láser, 2014, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: Hasta 24 hs, Idioma: Español.
# Asistencia
#
#
# 99$^a$ Reunión Nacional de la Asociación Física Argentina, 2014, Buenos Aires, Argentina, Duración: Congreso de 1 semana, Idioma: Español.
# Asistencia
#
#
# Information Processing in Biological Systems: From cells to equations--and back, 2013, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: Congreso de 1 semana, Idioma: Inglés.
# Asistencia
#
#
# Taller de Desarrollo del Comportamiento Emprendedor, 2011, Facultad de Ciencias Exactas y Naturales, U.B.A., Duración: 50 hs, Idioma: Español.
# Empretec
# Organiza con Naciones Unidas
#
#
# Taller de pedagogía, 2009, Facultad de Cs. Biomédicas, Hospital Universitario Austral, Duración: 60 hs, Idioma: Español.
# Asistencia con exámen

# %% [markdown]
# # Divulgacion Cientifica

# %%
for content in cv_data['Producción']['Divulgación Científica']:
    try:
        print(f"{content['name']}, {content['date']}, {content['location']}.\n{'\n'.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Semana de  la Física, 2016, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Charla: "Luces de la Semana"
# Preparación
#
#
# Semana de la  Física, 2015, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Estación de óptica
# Expositor
#
#
# Semana de la Física, 2014, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Estación de óptica
# Expositor
#
#
# Tecnópolis, 2013, Buenos Aires, Argentina.
# Expositor en Stand de Física
# Septiembre y Octubre

# %% [markdown]
# Semana de  la Física, 2016, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Charla: "Luces de la Semana"
# Preparación
#
#
# Semana de la  Física, 2015, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Estación de óptica
# Expositor
#
#
# Semana de la Física, 2014, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Estación de óptica
# Expositor
#
#
# Tecnópolis, 2013, Buenos Aires, Argentina.
# Expositor en Stand de Física
# Septiembre y Octubre

# %% [markdown]
# # Experiencia Profesional

# %%
for content in cv_data['Experiencia']['Profesionales']:
    try:
        print(f"{content['name']}, {content['date']}, {content['location']}.\n{'\n'.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Bohus Biotech, 2025, Uppsala, Suecia.
# Consulta independiente para desarrollar de algoritmos de análisis de imágenes para evaluar la calidad de productos estéticos.
#
#
# Detección de interacciones proteína-proteína mediante ensayos de ligando proteína, 2025, Navinci, Uppsala, Suecia.
# Desarrollar algoritmos de análisis de imágenes para la detección de interacciones proteína-proteína.
#
#
# Servicio Técnico de Alto Nivel, 2019, Laboratorio de Electrónica Cuántica, Facultad de Ciencias Exactas y Naturales, U.B.A..
# ST4407, Colaboración con Y-Tec, Petrografía Digital

# %% [markdown]
# ## Otra produccion

# %%
for content in cv_data['Producción']['Otros']:
    try:
        print(f"{content['name']}, {content['date']}, {content['authors']}, DOI: {content['doi']}: {content['type']}.\n{'\n'.join([content['description']])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# AI and Image Analysis, 2025, **Agustin Corbat**, Jonas Windhager, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15390210: Clase teórica y práctica publicada en Zenodo.
# Clase teórica y práctica para estudiantes de la universidad de agricultura que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# Image Analysis Lecture at Live Cell Imaging Microscopy Course, 2025, **Agustin Corbat**, Gisele Miranda, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15390210: Clase teórica publicada en Zenodo.
# Clase teórica para estudiantes que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# Image Analysis Workshop at Live Cell Imaging Facility Microscopy Course, 2025, Gisele Miranda, **Agustin Corbat**, Sylvie Le Guyader, DOI: 10.5281/zenodo.15390007: Taller publicado en Zenodo.
# Taller para demostrar a estudiantes que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# ...

# %% [markdown]
# AI and Image Analysis, 2025, **Agustin Corbat**, Jonas Windhager, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15390210: Clase teórica y práctica publicada en Zenodo.
# Clase teórica y práctica para estudiantes de la universidad de agricultura que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# Image Analysis Lecture at Live Cell Imaging Microscopy Course, 2025, **Agustin Corbat**, Gisele Miranda, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15390210: Clase teórica publicada en Zenodo.
# Clase teórica para estudiantes que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# Image Analysis Workshop at Live Cell Imaging Facility Microscopy Course, 2025, Gisele Miranda, **Agustin Corbat**, Sylvie Le Guyader, DOI: 10.5281/zenodo.15390007: Taller publicado en Zenodo.
# Taller para demostrar a estudiantes que se inician en proyectos de análisis de imágenes de microscopía.
#
#
# Image Artifacts that cannot be corrected post-acquisition: Bleedthrough, saturation/underexposure and soft focus, 2025, Gisele Miranda, **Agustin Corbat**, Gabriela Imreh, Sylvie Le Guyader, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15374754: dataset en Zenodo.
# Dataset de imágenes adquirido para demostrar el efecto de foco, exposición y sangrado espectral en el análisis de imágenes de microscopía.
#
#
# Uneven illumination and uneven focus correction, 2025, Gisele Miranda, **Agustin Corbat**, Gabriela Imreh, Sylvie Le Guyader, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15374885: dataset en Zenodo.
# Dataset de imágenes adquirido para demostrar el efecto de la inhomogeneidad de iluminación en el análisis de imágenes de microscopía.
#
#
# Microscopy nuclei dataset with decreasing noise level by increasing averaging, 2025, Gisele Miranda, **Agustin Corbat**, Gabriela Imreh, Sylvie Le Guyader, Anna Klemm, Carolina Wählby, DOI: 10.5281/zenodo.15175309: dataset en Zenodo.
# Dataset de imágenes adquirido para demostrar el efecto del ruido de adquisición en el análisis de imágenes  de microscopía.
#
#
# A 3D human motor neuron disease platform for high throughput drug screening, 2025, Katharina Hennig, Afonso Malheiro, Edgar R. Gomes, Agustin Corbat, DOI: 10.6019/S-BIAD1737: dataset en BioImage Archive.
# Set de datos que consiste de dos imágenes de una neuroesfera conformada por human induced Pluripotent Stem Cells (hiPSC) derivadas de motoneuronas, ona tratada con 5 µM MI132 para inducir formacion de granulos de estres y la otra sin tratar.
#
#
# AI4Life Open Call 2: Project 38, 2025, Agustin Corbat, DOI: 10.5281/zenodo.15088621: Repositorio de código.
# Flujo de análisis de imágenes desarrollado para AI4Life open call 2 proyecto 38: Neuroscan.

# %% [markdown]
# # Educacion

# %%
for content in cv_data['Educación']['Educación Universitaria']:
    try:
        print(f"{content['name']}, {content['date']}, {content['location']}.\n{'\n'.join(content['description'])}")
        print("\n")
    except KeyError:
        print(content)
# Out:
# Doctorado en Ciencias Físicas, 2016--2021, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Microespectroscopía aplicada a la cuantificación y modelado de la propagación de señales en redes biológicas
# Director: Hernán E. Grecco, Nota: Sobresaliente
#
#
# Licenciatura en Ciencias Físicas, 2011--2016, Facultad de Ciencias Exactas y Naturales, U.B.A..
# Promedio: **9,32**
#
#
# Medicina, Ciclo Troncal Completo, 2008--2010, Facultad de Ciencias Biomédicas, Hospital Universitario Austral..
# Beca al Mérito
# Promedio: **7,48**
